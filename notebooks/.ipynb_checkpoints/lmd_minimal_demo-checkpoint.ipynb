# %% [markdown]
# # LMD Demo
# Preprocesses (PCA + neighbors) and computes LMD

# %%
import scanpy as sc
import rapids_singlecell as rsc
import numpy as np
import pandas as pd
import sys
import os
import matplotlib.pyplot as plt
import cupyx as cpx
from pylmd.lmd import lmd
import time

# %%
adata_cpu = sc.read_10x_h5("/mnt/d/scRNA/wtwoundfiltered_feature_bc_matrix.h5")
adata_cpu.var_names_make_unique()
# Out:
# /home/jasson/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/jasson/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata_gpu = sc.read_10x_h5("/mnt/d/scRNA/wtwoundfiltered_feature_bc_matrix.h5")
adata_gpu.var_names_make_unique()
adata_gpu.X = cpx.scipy.sparse.csr_matrix(adata_gpu.X)
# Out:
# /home/jasson/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/jasson/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata_cpu
# Out:
# AnnData object with n_obs × n_vars = 4305 × 31053
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
adata_gpu
# Out:
# AnnData object with n_obs × n_vars = 4305 × 31053
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
start = time.perf_counter()

sc.pp.filter_cells(adata_cpu, min_genes=100)
sc.pp.filter_genes(adata_cpu, min_cells=3)
sc.pp.normalize_total(adata_cpu)
sc.pp.log1p(adata_cpu)

sc.pp.highly_variable_genes(adata_cpu, n_top_genes=2000)
sc.pp.scale(adata_cpu,max_value=10)

sc.tl.pca(adata_cpu)
sc.pp.neighbors(adata_cpu)
sc.tl.umap(adata_cpu)

end = time.perf_counter()
print(f"Elapsed time: {end - start} seconds")
# Out:
# Elapsed time: 15.262945792999744 seconds

# %%
start = time.perf_counter()

rsc.pp.normalize_total(adata_gpu)
rsc.pp.log1p(adata_gpu)

rsc.pp.highly_variable_genes(adata_gpu, n_top_genes=2000)
rsc.pp.scale(adata_gpu,max_value=10)

rsc.tl.pca(adata_gpu)
rsc.pp.neighbors(adata_gpu)
rsc.tl.umap(adata_gpu)

end = time.perf_counter()
print(f"Elapsed time: {end - start} seconds")
# Out:
# Elapsed time: 1.922113590000663 seconds

# %%
start = time.perf_counter()

# Compute LMD
res_cpu = lmd(adata_cpu, n_neighbors=15, use_rep='X_pca', max_time_pow=6, min_cells=3, correction=False, device='cpu')

end = time.perf_counter()
print(f"Elapsed time: {end - start} seconds")
# Out:
# Elapsed time: 16.057062920001044 seconds

# %%
type(adata_gpu)
# Out:
# anndata._core.anndata.AnnData

# %%
start = time.perf_counter()

# Compute LMD
res_gpu = lmd(adata_gpu, n_neighbors=15, use_rep='X_pca', max_time_pow=6, min_cells=3, correction=False, device='gpu')

end = time.perf_counter()
print(f"Elapsed time: {end - start} seconds")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17104/398828690.py in <module>
#       2
#       3 # Compute LMD
# ----> 4 res_gpu = lmd(adata_gpu, n_neighbors=15, use_rep='X_pca', max_time_pow=6, min_cells=3, correction=False, device='gpu')
#       5
#       6 end = time.perf_counter()
#
# /mnt/j/docker/pylmd/pylmd/pylmd/lmd.py in lmd(adata, n_neighbors, use_rep, max_time_pow, min_cells, correction, device)
#     143         raise ValueError("Expression and graph dimension mismatch: genes x cells vs cells x cells")
#     144
# --> 145     scores = fast_calculate_score_profile(W=W, init_state=rho, max_time_pow=max_time_pow, device=device)
#     146     lmds = obtain_lmds(scores, correction=correction, device=device)
#     147
#
# /mnt/j/docker/pylmd/pylmd/pylmd/lmd.py in fast_calculate_score_profile(W, init_state, max_time_pow, device)
#      66     final_state = xp.ones((n,), dtype=xp.float32) / n
#      67     # doubly stochastic transition matrix P
# ---> 68     P = sinkhorn_bistochastic(_to_dense(W), xp=xp)
#      69
#      70     # Dyadic diffusion times: 0, 2, 4, ..., 2^max_time_pow
#
# /mnt/j/docker/pylmd/pylmd/pylmd/utils.py in sinkhorn_bistochastic(W, max_iter, tol, xp)
#      77         r_old = r
#      78         c_old = c
# ---> 79         r = 1.0 / (Wd @ c.T + 1e-12)
#      80         c = 1.0 / (r.T @ Wd + 1e-12)
#      81         if xp.max(xp.abs(r - r_old)) < tol and xp.max(xp.abs(c - c_old)) < tol:
#
# cupy/_core/core.pyx in cupy._core.core._ndarray_base.__array_ufunc__()
#
# ~/anaconda3/lib/python3.9/site-packages/cupy/_core/_gufuncs.py in __call__(self, *args, **kwargs)
#     656                 ' but %s given' % (len(input_coredimss), len(args)))
#     657
# --> 658         args, dimsizess, loop_output_dims, outs, m_dims = self._get_args_transposed(  # NOQA
#     659             args, input_axes, outs, output_axes)
#     660
#
# ~/anaconda3/lib/python3.9/site-packages/cupy/_core/_gufuncs.py in _get_args_transposed(self, args, input_axes, outs, output_axes)
#     470         shape = internal._broadcast_shapes(
#     471             [a.shape[:-len(self._input_coredimss)] for a in args])
# --> 472         args = [_manipulation.broadcast_to(
#     473             a, shape + a.shape[-len(self._input_coredimss):]) for a in args]
#     474
#
# ~/anaconda3/lib/python3.9/site-packages/cupy/_core/_gufuncs.py in <listcomp>(.0)
#     470         shape = internal._broadcast_shapes(
#     471             [a.shape[:-len(self._input_coredimss)] for a in args])
# --> 472         args = [_manipulation.broadcast_to(
#     473             a, shape + a.shape[-len(self._input_coredimss):]) for a in args]
#     474
#
# TypeError: Argument 'array' has incorrect type (expected cupy._core.core._ndarray_base, got numpy.ndarray)

# %%
# Show top genes
genes_cpu = res_cpu['genes'] if res_cpu['genes'] is not None else [f'gene_{i}' for i in range(n_genes)]
order_cpu = res_cpu['rank']
lmds_cpu = res_cpu['lmds']

# %%
plt.plot([lmds_cpu[i] for i in order_cpu[::100]], [genes_cpu[i] for i in order_cpu[::100]])

# %%
res_cpu['knee_index']
# Out:
# 16373

# %%
res_cpu['score_profile']
# Out:
# {'score0_0': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  'score0_2': array([3.5343928e+00, 6.0630566e+02, 6.5823501e+08, ..., 1.5844788e+09,
#         1.3734710e+09, 3.6260971e+01], dtype=float32),
#  'score0_4': array([5.6021938e+00, 3.8210962e+02, 6.1687168e+08, ..., 1.4962509e+09,
#         3.2412678e+08, 5.0665337e+01], dtype=float32),
#  'score0_8': array([7.4260516e+00, 4.0597345e+02, 7.4246592e+08, ..., 1.8182036e+09,
#         6.3936262e+08, 5.8688438e+01], dtype=float32),
#  'score0_16': array([8.5134907e+00, 4.7457019e+02, 8.4049510e+08, ..., 1.9656312e+09,
#         8.6361427e+08, 6.3611973e+01], dtype=float32),
#  'score0_32': array([9.1113558e+00, 6.2231525e+02, 9.0283302e+08, ..., 1.9282785e+09,
#         9.5827725e+08, 6.3779488e+01], dtype=float32),
#  'score0_64': array([9.95844078e+00, 1.00793274e+03, 8.98633728e+08, ...,
#         1.88171392e+09, 9.73965568e+08, 6.06393509e+01], dtype=float32),
#  'entropy': array([-3.2462797e+00, -3.6777056e+03, -7.7355322e+08, ...,
#         -1.9738276e+09, -1.2562944e+09, -2.1866951e+01], dtype=float32),
#  'max_score0': array([3.2462797e+00, 3.6777056e+03, 7.7355322e+08, ..., 1.9738276e+09,
#         1.2562944e+09, 2.1866951e+01], dtype=float32)}

# %%
res_cpu['score_profile']
# Out:
# {'score0_0': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  'score0_2': array([3.5343928e+00, 6.0630566e+02, 6.5823501e+08, ..., 1.5844788e+09,
#         1.3734710e+09, 3.6260971e+01], dtype=float32),
#  'score0_4': array([5.6021938e+00, 3.8210962e+02, 6.1687168e+08, ..., 1.4962509e+09,
#         3.2412678e+08, 5.0665337e+01], dtype=float32),
#  'score0_8': array([7.4260516e+00, 4.0597345e+02, 7.4246592e+08, ..., 1.8182036e+09,
#         6.3936262e+08, 5.8688438e+01], dtype=float32),
#  'score0_16': array([8.5134907e+00, 4.7457019e+02, 8.4049510e+08, ..., 1.9656312e+09,
#         8.6361427e+08, 6.3611973e+01], dtype=float32),
#  'score0_32': array([9.1113558e+00, 6.2231525e+02, 9.0283302e+08, ..., 1.9282785e+09,
#         9.5827725e+08, 6.3779488e+01], dtype=float32),
#  'score0_64': array([9.95844078e+00, 1.00793274e+03, 8.98633728e+08, ...,
#         1.88171392e+09, 9.73965568e+08, 6.06393509e+01], dtype=float32),
#  'entropy': array([-3.2462797e+00, -3.6777056e+03, -7.7355322e+08, ...,
#         -1.9738276e+09, -1.2562944e+09, -2.1866951e+01], dtype=float32),
#  'max_score0': array([3.2462797e+00, 3.6777056e+03, 7.7355322e+08, ..., 1.9738276e+09,
#         1.2562944e+09, 2.1866951e+01], dtype=float32)}

# %%
scores_over_time = []

for i in res_cpu['score_profile']:
    if i.startswith('score'):
        scores_over_time.append(res_cpu['score_profile'][i][2000])
        
plt.plot(scores_over_time)

# %%
scores_over_time = []

for i in res_cpu['score_profile']:
    if i.startswith('score'):
        scores_over_time.append(res_cpu['score_profile'][i][1])
        
plt.plot(scores_over_time)

# %%
# Show top genes
genes_gpu = res_gpu['genes'] if res_gpu['genes'] is not None else [f'gene_{i}' for i in range(n_genes)]
order_gpu = res_gpu['rank']
lmds_gpu = res_gpu['lmds']

# %%
top_gpu = [(genes_gpu[i], float(lmds_gpu[i])) for i in order_gpu[:10]]
top_gpu

# %%
genes_cpu[:10]
# Out:
# ['Xkr4',
#  'Sox17',
#  'Mrpl15',
#  'Lypla1',
#  'Gm37988',
#  'Tcea1',
#  'Rgs20',
#  'Atp6v1h',
#  'Rb1cc1',
#  '4732440D04Rik']

# %%
top_cpu = [(genes_cpu[i], float(lmds_cpu[i])) for i in order_cpu[:10]]
top_cpu
# Out:
# [('Siglech', 0.15059266984462738),
#  ('Klk1', 0.1700821965932846),
#  ('Col1a2', 0.21674171090126038),
#  ('Ccr9', 0.24626925587654114),
#  ('Cox6a2', 0.31140342354774475),
#  ('Cd3e', 0.3215180039405823),
#  ('Ebf1', 0.336525559425354),
#  ('Tcrg-C1', 0.3428158164024353),
#  ('Egfl7', 0.34426864981651306),
#  ('Icos', 0.3582254648208618)]

# %%
bot_gpu = [(genes_gpu[i], float(lmds_gpu[i])) for i in order_gpu[(len(order_gpu) - 10):]]
bot_gpu

# %%
bot_cpu = [(genes_cpu[i], float(lmds_cpu[i])) for i in order_cpu[(len(order_cpu) - 10):]]
bot_cpu
# Out:
# [('Gm27240', 36.99828338623047),
#  ('Trav2', 37.49367141723633),
#  ('Trav7-3', 37.6016731262207),
#  ('Trav4-2', 37.661441802978516),
#  ('Gm10717', 37.88094711303711),
#  ('Gm9918', 37.97816467285156),
#  ('Pou4f1', 38.10714340209961),
#  ('Trav13-2', 38.43130874633789),
#  ('Lime1', 38.99842071533203),
#  ('Krt24', 39.260982513427734)]

# %%
top_genes_gpu = [(genes_gpu[i]) for i in order_gpu[:20]]
top_genes_gpu

# %%
top_genes_cpu = [(genes_cpu[i]) for i in order_cpu[:20]]
top_genes_cpu
# Out:
# ['Siglech',
#  'Klk1',
#  'Col1a2',
#  'Ccr9',
#  'Cox6a2',
#  'Cd3e',
#  'Ebf1',
#  'Tcrg-C1',
#  'Egfl7',
#  'Icos',
#  'Cxcr6',
#  'Cd163l1',
#  'Col5a1',
#  'Iglc3',
#  'Myct1',
#  'Col5a2',
#  'Il2rb',
#  'Trbc2',
#  'Gpihbp1',
#  'Ptprb']

# %%
bot_genes_gpu = [(genes_gpu[i]) for i in order_gpu[(len(order_gpu) - 10):]]
bot_genes_gpu

# %%
bot_genes_cpu = [(genes_cpu[i]) for i in order_cpu[(len(order_cpu) - 10):]]
bot_genes_cpu
# Out:
# ['Gm27240',
#  'Trav2',
#  'Trav7-3',
#  'Trav4-2',
#  'Gm10717',
#  'Gm9918',
#  'Pou4f1',
#  'Trav13-2',
#  'Lime1',
#  'Krt24']

# %%
sc.pl.umap(adata_gpu, color = top_genes_gpu)

# %%
sc.pl.umap(adata_cpu, color = top_genes_cpu)

# %%
sc.pl.umap(adata_gpu, color = bot_genes_gpu)

# %%
sc.pl.umap(adata_cpu, color = bot_genes_cpu)

# %%
check_genes_cpu = [(genes_cpu[i]) for i in order_cpu[::1000]]
check_genes_cpu
sc.pl.umap(adata_cpu, color = check_genes_cpu)
