# %% [markdown]
# ## Welcome to PyLMD!
#
# This notebook demonstrates how you can use the Localized Marker Detector algorithm to identify genes whose expression is restricted to particular groups of similar cells.

# %% [markdown]
# First import the necessary libraries, including pylmd. To install pylmd, please clone the repository from https://github.com/jassonmakkar/pylmd and run "pip install -e ." in the download directory.

# %%
import sys
import os
from pylmd import lmd, utils, cluster, plot
import scanpy as sc
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import warnings

# %% [markdown]
# Define the device you will be using to perform the analysis. **IMPORTANT** Please use 'gpu' here if you have an NVIDIA GPU and have installed CUDA, CuPy, and RAPIDS-singlecell.

# %%
device = 'gpu'
max_time = 2**20

# %%
# Retreive the necessary packages based on selected device type.
device_libs = lmd.get_xp(device)

# %%
xsc = device_libs['xsc']

# %%
url = "https://datasets.cellxgene.cziscience.com/"
file = "207e1f5f-9395-4d39-93cd-73aeb689c1e7.h5ad"
download_direc = 'downloads'
path = os.path.join(download_direc, file)

os.makedirs(download_direc, exist_ok=True)

response = requests.get((url + file), stream=True)
response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)

if os.path.exists(path):
    print('Using cached data.')
    
else:
    with open(path, 'wb') as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)
    print(f'Downloaded {file}.')
# Out:
# Using cached data.

# %%
# Read in data from path.
adata = sc.read_h5ad(path)

# %%
adata.var_names_make_unique()

# %%
# For any datasets downloaded from CellxGene - Default is Accession Numbers, not Gene Symbols (use 'Gene' / 'feature_name')
adata.var_names = adata.var['feature_name']
# Out:
# /opt/conda/lib/python3.12/site-packages/anndata/_core/anndata.py:835: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['ENSG00000238009', 'ENSG00000241860', 'ENSG00000241599', 'LINC01409', 'LINC01128']
#
#     Inferred to be: categorical
#
#   names = self._prep_dim_index(names, "var")

# %%
adata.var
# Out:
#                 gene_symbols  feature_is_filtered     feature_name  \
# feature_name
# ENSG00000238009   AL627309.1                False  ENSG00000238009
# ENSG00000241860   AL627309.5                False  ENSG00000241860
# ENSG00000241599   AL627309.4                False  ENSG00000241599
# LINC01409          LINC01409                False        LINC01409
# LINC01128          LINC01128                False        LINC01128
# ...                      ...                  ...              ...
# PAGE5                  PAGE5                False            PAGE5
# NXF2B                  NXF2B                False            NXF2B
# TRPC5OS              TRPC5OS                False          TRPC5OS
# MAGEC3                MAGEC3                False           MAGEC3
# AVPR2                  AVPR2                False            AVPR2
#
#                 feature_reference feature_biotype feature_length  \
# feature_name
# ENSG00000238009    NCBITaxon:9606            gene            629
# ENSG00000241860    NCBITaxon:9606            gene           1025
# ENSG00000241599    NCBITaxon:9606            gene            457
# LINC01409          NCBITaxon:9606            gene           1059
# LINC01128          NCBITaxon:9606            gene           1627
# ...                           ...             ...            ...
# PAGE5              NCBITaxon:9606            gene            553
# NXF2B              NCBITaxon:9606            gene           2143
# TRPC5OS            NCBITaxon:9606            gene           2779
# MAGEC3             NCBITaxon:9606            gene           1290
# AVPR2              NCBITaxon:9606            gene           1601
#
#                    feature_type
# feature_name
# ENSG00000238009          lncRNA
# ENSG00000241860          lncRNA
# ENSG00000241599          lncRNA
# LINC01409                lncRNA
# LINC01128                lncRNA
# ...                         ...
# PAGE5            protein_coding
# NXF2B            protein_coding
# TRPC5OS          protein_coding
# MAGEC3           protein_coding
# AVPR2            protein_coding
#
# [25691 rows x 7 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 15806 × 25691
#     obs: 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'suspension_type', 'model_id', 'sample_id', 'Phase', 'level_1', 'level_2', 'level_3', 'CountUMIs', 'CountGenes', 'X.Mitochondrial', 'NoveltyScore', 'nCount_SCT', 'nFeature_SCT', 'orig.ident', 'is_primary_data', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'gene_symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'citation', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_ref.umap', 'X_umap'

# %%
# Move data to the GPU (if selected)
if device == 'gpu':
    xsc.get.anndata_to_GPU(adata)

# %%
# Filter cells and genes (default: filter cells with < 100 genes = 100; filter genes expressed in < 3 cells)
xsc.pp.filter_cells(adata, min_genes=100)
xsc.pp.filter_genes(adata, min_cells=3)
# Out:
# /opt/conda/lib/python3.12/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# filtered out 1 genes that are detected in less than 3 cells
# /opt/conda/lib/python3.12/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
# Copy adata object to preserve raw counts.
raw_adata = adata.copy()

# %%
# Extract raw gene x cell expression matrix.
dat = pd.DataFrame(
    raw_adata.X.get().T.toarray() if not isinstance(raw_adata.X, np.ndarray) else raw_adata.X.T,
    index=adata.var_names,       # genes
    columns=adata.obs_names      # cells
)

# %%
dat
# Out:
#                  N2_O1_AAACGAAAGTCGCCAC-1  N2_O1_AAACGAAGTTAGCTAC-1  \
# feature_name
# ENSG00000238009                       0.0                       0.0
# ENSG00000241860                       0.0                       0.0
# ENSG00000241599                       0.0                       0.0
# LINC01409                             0.0                       0.0
# LINC01128                             0.0                       0.0
# ...                                   ...                       ...
# PAGE5                                 0.0                       0.0
# NXF2B                                 0.0                       0.0
# TRPC5OS                               0.0                       0.0
# MAGEC3                                0.0                       0.0
# AVPR2                                 0.0                       0.0
#
#                  N2_O1_AAACGAATCCTCTCTT-1  N2_O1_AAACGCTCACTGCACG-1  \
# feature_name
# ENSG00000238009                  0.000000                       0.0
# ENSG00000241860                  0.000000                       0.0
# ENSG00000241599                  0.000000                       0.0
# LINC01409                        0.175024                       0.0
# LINC01128                        0.000000                       0.0
# ...                                   ...                       ...
# PAGE5                            0.000000                       0.0
# NXF2B                            0.000000                       0.0
# TRPC5OS                          0.000000                       0.0
# MAGEC3                           0.000000                       0.0
# AVPR2                            0.000000                       0.0
#
#                  N2_O1_AAAGAACGTAGCTCGC-1  N2_O1_AAAGAACTCGTAACAC-1  \
# feature_name
# ENSG00000238009                       0.0                       0.0
# ENSG00000241860                       0.0                       0.0
# ENSG00000241599                       0.0                       0.0
# LINC01409                             0.0                       0.0
# LINC01128                             0.0                       0.0
# ...                                   ...                       ...
# PAGE5                                 0.0                       0.0
# NXF2B                                 0.0                       0.0
# TRPC5OS                               0.0                       0.0
# MAGEC3                                0.0                       0.0
# AVPR2                                 0.0                       0.0
#
#                  N2_O1_AAAGAACTCTGAACGT-1  N2_O1_AAAGGATCACCAACAT-1  \
# feature_name
# ENSG00000238009                  0.000000                       0.0
# ENSG00000241860                  0.000000                       0.0
# ENSG00000241599                  0.000000                       0.0
# LINC01409                        0.000000                       0.0
# feature_name
# ENSG00000238009                          0.0                     0.194678
# ENSG00000241860                          0.0                     0.000000
# ENSG00000241599                          0.0                     0.000000
# LINC01409                                0.0                     0.000000
# LINC01128                                0.0                     0.000000
# ...                                      ...                          ...
# PAGE5                                    0.0                     0.000000
# NXF2B                                    0.0                     0.000000
# TRPC5OS                                  0.0                     0.000000
# MAGEC3                                   0.0                     0.000000
# AVPR2                                    0.0                     0.000000
#
# [25690 rows x 15806 columns]

# %%
# Perform normalization, feature selection, scaling, and dimensional reduction.
xsc.pp.normalize_total(adata)
xsc.pp.log1p(adata)
xsc.pp.highly_variable_genes(adata, n_top_genes=2000)
xsc.pp.scale(adata,max_value=10)
xsc.tl.pca(adata)
xsc.get.anndata_to_CPU(adata)
xsc.pp.neighbors(adata)
xsc.tl.umap(adata)

# %%
# Plot of UMAP coordinates.
sc.pl.umap(adata)

# %%
# Selects genes that have higher than median expression in at least 10 cells and removes genes expressed in greater than 30% of cells (moderately expressed genes)
cell_medians = np.median(dat, axis=0)
mask = dat > cell_medians

gene_detected_count = mask.sum(axis=1)

selected_genes = (gene_detected_count >= 10) & (gene_detected_count <= dat.shape[1] * 0.3)

# %%
# Filters objects for selected genes.
adata = adata[:, selected_genes].copy()
raw_adata = raw_adata[:, selected_genes].copy()
dat = dat[selected_genes]
# Out:
# /opt/conda/lib/python3.12/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 15806 × 15355
#     obs: 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'suspension_type', 'model_id', 'sample_id', 'Phase', 'level_1', 'level_2', 'level_3', 'CountUMIs', 'CountGenes', 'X.Mitochondrial', 'NoveltyScore', 'nCount_SCT', 'nFeature_SCT', 'orig.ident', 'is_primary_data', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_counts', 'n_genes'
#     var: 'gene_symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'citation', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title', 'log1p', 'hvg', 'pca', 'neighbors', 'umap', 'cell_type_colors'
#     obsm: 'X_ref.umap', 'X_umap', 'X_pca'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
# Extracts top 20 PCs
feature_space = adata.obsm['X_pca'][:, :20]

# %%
# Builds an affinity network for connecting cells based on similarity.
W = lmd.build_network(feature_space, n_neighbors=5)

# %%
W
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 115472 stored elements and shape (15806, 15806)>

# %%
plot.visualize_network(W, adata)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
rho = lmd.rowwise_normalize(dat, W)

# %%
rho
# Out:
#                  N2_O1_AAACGAAAGTCGCCAC-1  N2_O1_AAACGAAGTTAGCTAC-1  \
# ENSG00000238009                       0.0                       0.0
# ENSG00000241860                       0.0                       0.0
# ENSG00000241599                       0.0                       0.0
# LINC01409                             0.0                       0.0
# LINC01128                             0.0                       0.0
# ...                                   ...                       ...
# ENSG00000228933                       0.0                       0.0
# NUDT10                                0.0                       0.0
# PAGE5                                 0.0                       0.0
# NXF2B                                 0.0                       0.0
# TRPC5OS                               0.0                       0.0
#
#                  N2_O1_AAACGAATCCTCTCTT-1  N2_O1_AAACGCTCACTGCACG-1  \
# ENSG00000238009                  0.000000                       0.0
# ENSG00000241860                  0.000000                       0.0
# ENSG00000241599                  0.000000                       0.0
# LINC01409                        0.000307                       0.0
# LINC01128                        0.000000                       0.0
# ENSG00000241599                     0.000000                          0.0
# LINC01409                           0.000000                          0.0
# LINC01128                           0.000192                          0.0
# ...                                      ...                          ...
# ENSG00000228933                     0.000000                          0.0
# NUDT10                              0.000000                          0.0
# PAGE5                               0.000000                          0.0
# NXF2B                               0.000000                          0.0
# TRPC5OS                             0.000000                          0.0
#
#                  N3_ALIEX_TTTGGAGCAAGCAGGT-1  N3_ALIEX_TTTGGTTGTATACCCA-1  \
# ENSG00000238009                          0.0                          0.0
# ENSG00000241860                          0.0                          0.0
# ENSG00000241599                          0.0                          0.0
# LINC01409                                0.0                          0.0
# LINC01128                                0.0                          0.0
# ...                                      ...                          ...
# ENSG00000228933                          0.0                          0.0
# NUDT10                                   0.0                          0.0
# PAGE5                                    0.0                          0.0
# NXF2B                                    0.0                          0.0
# TRPC5OS                                  0.0                          0.0
#
#                  N3_ALIEX_TTTGGTTTCTGAATGC-1  N3_ALIEX_TTTGTTGGTCGCATGC-1
# ENSG00000238009                          0.0                     0.001888
# ENSG00000241860                          0.0                     0.000000
# ENSG00000241599                          0.0                     0.000000
# LINC01409                                0.0                     0.000000
# LINC01128                                0.0                     0.000000
# ...                                      ...                          ...
# ENSG00000228933                          0.0                     0.000000
# NUDT10                                   0.0                     0.000000
# PAGE5                                    0.0                     0.000000
# NXF2B                                    0.0                     0.000000
# TRPC5OS                                  0.0                     0.000000
#
# [15355 rows x 15806 columns]

# %%
# Constructs the diffusion operators to describe diffusion across this network agnostic of individual gene expression.
P_ls = lmd.construct_diffusion_operators(W, device_libs, max_time)
# Out:
# Creating diffusion operators...
# Step 1: max deviation from convergence = 15806.0
# Step 2: max deviation from convergence = 81438512.0
# Step 3: max deviation from convergence = 34117992.0
# Step 4: max deviation from convergence = 23263098.0
# Step 5: max deviation from convergence = 17826052.0
# Step 6: max deviation from convergence = 13417905.0
# Step 7: max deviation from convergence = 8344799.0
# Step 8: max deviation from convergence = 3501476.75
# Step 9: max deviation from convergence = 994619.4375
# Step 10: max deviation from convergence = 443366.28125
# Step 11: max deviation from convergence = 351043.25
# Step 12: max deviation from convergence = 226186.46875
# Step 13: max deviation from convergence = 94187.0625
# Step 14: max deviation from convergence = 50587.84375
# Step 15: max deviation from convergence = 35749.71484375
# Step 16: max deviation from convergence = 17955.2109375
# Step 17: max deviation from convergence = 4637.904296875
# Converged at step 17 (time = 65536)
# Max diffusion time: 65536
# Total operators created: 17

# %%
P_ls
# Out:
# {0: <cupyx.scipy.sparse._csr.csr_matrix at 0x7f91736af0e0>,
#  2: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f91b016f2c0>,
#  4: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5d8e540>,
#  8: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5c36720>,
#  16: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5c35040>,
#  32: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5d04aa0>,
#  64: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f913af64da0>,
#  128: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5d04110>,
#  256: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f9173d222a0>,
#  512: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5d8e990>,
#  1024: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f913af66720>,
#  2048: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5c36480>,
#  4096: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5d619a0>,
#  8192: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5d069c0>,
#  16384: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f913af657f0>,
#  32768: <cupyx.scipy.sparse._csc.csc_matrix at 0x7f90a5
# SDR42E1     15.400255
# ZNF142      15.432411
# Name: LMDS, dtype: float64

# %%
top = list(sort_score.index[:4])
bot = list(sort_score.index[int(len(sort_score)-4):])

# %%
adata.var_names
# Out:
# CategoricalIndex(['ENSG00000238009', 'ENSG00000241860', 'ENSG00000241599',
#                   'LINC01409', 'LINC01128', 'LINC00115', 'FAM41C',
#                   'ENSG00000272438', 'ENSG00000230699', 'LINC02593',
#                   ...
#                   'LINC01664', 'ENSG00000279440', 'PVALB', 'ENSG00000287171',
#                   'TLR7', 'ENSG00000228933', 'NUDT10', 'PAGE5', 'NXF2B',
#                   'TRPC5OS'],
#                  categories=['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3'], ordered=False, dtype='category', name='feature_name', length=15355)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 15806 × 15355
#     obs: 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'suspension_type', 'model_id', 'sample_id', 'Phase', 'level_1', 'level_2', 'level_3', 'CountUMIs', 'CountGenes', 'X.Mitochondrial', 'NoveltyScore', 'nCount_SCT', 'nFeature_SCT', 'orig.ident', 'is_primary_data', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_counts', 'n_genes'
#     var: 'gene_symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'citation', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title', 'log1p', 'hvg', 'pca', 'neighbors', 'umap', 'cell_type_colors'
#     obsm: 'X_ref.umap', 'X_umap', 'X_pca'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata.var
# Out:
#                 gene_symbols  feature_is_filtered     feature_name  \
# feature_name
# ENSG00000238009   AL627309.1                False  ENSG00000238009
# ENSG00000241860   AL627309.5                False  ENSG00000241860
# ENSG00000241599   AL627309.4                False  ENSG00000241599
# LINC01409          LINC01409                False        LINC01409
# LINC01128          LINC01128                False        LINC01128
# ...                      ...                  ...              ...
# ENSG00000228933   AC107419.1                False  ENSG00000228933
# NUDT10                NUDT10                False           NUDT10
# PAGE5                  PAGE5                False            PAGE5
# NXF2B                  NXF2B                False            NXF2B
# TRPC5OS              TRPC5OS                False          TRPC5OS
#
#                 feature_reference feature_biotype feature_length  \
# feature_name
# ENSG00000238009    NCBITaxon:9606            gene            629
# ENSG00000241860    NCBITaxon:9606            gene           1025
# ENSG00000241599    NCBITaxon:9606            gene            457
# LINC01409          NCBITaxon:9606            gene           1059
# LINC01128          NCBITaxon:9606            gene           1627
# ...                           ...             ...            ...
# ENSG00000228933    NCBITaxon:9606            gene            969
# NUDT10             NCBITaxon:9606            gene           1963
# PAGE5              NCBITaxon:9606            gene            553
# NXF2B              NCBITaxon:9606            gene           2143
# TRPC5OS            NCBITaxon:9606            gene           2779
#
#                    feature_type    n_counts  n_cells  highly_variable  \
# feature_name
# ENSG00000238009          lncRNA  103.094342      683            False
# ENSG00000241860          lncRNA  139.941030      938            False
# ENSG00000241599          lncRNA    4.358753       14             True
# LINC01409                lncRNA  569.726754     3129            False
# LINC01128                lncRNA  725.570385     4217            False
# ...                         ...         ...      ...              ...
# ENSG00000228933          lncRNA    3.703158       12            False
# NUDT10           protein_coding    1.503301       10            False
# PAGE5            protein_coding    2.976101       18            False
# NXF2B            protein_coding    2.905183       12            False
# TRPC5OS          protein_coding    2.112197       11            False
#
#                     means  dispersions  dispersions_norm      mean       std
# feature_name
# ENSG00000238009  0.006357    -1.686158         -0.755475  0.005849  0.030823
# ENSG00000241860  0.008617    -1.684238         -0.750004  0.007931  0.035800
# ENSG00000241599  0.000300    -0.661817          2.164237  0.000245  0.009624
# LINC01409        0.034562    -1.487163         -0.188275  0.031433  0.076009
# LINC01128        0.045026    -1.658519         -0.676696  0.041509  0.081328
# ...                   ...          ...               ...       ...       ...
# ENSG00000228933  0.000242    -1.016599          1.152990  0.000208  0.007880
# NUDT10           0.000112    -1.696856         -0.785969  0.000103  0.004142
# PAGE5            0.000187    -1.702950         -0.803340  0.000172  0.005328
# NXF2B            0.000164    -1.362355          0.167469  0.000146  0.005690
# TRPC5OS          0.000133    -1.522557         -0.289158  0.000120  0.004807
#
# [15355 rows x 15 columns]

# %%
sc.pl.umap(adata, color = top, use_raw=False)

# %%
sc.pl.umap(adata, color = bot, use_raw=False)

# %%
plot.visualize_score_pattern(norm_scores, genes = top + bot)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Gene Scores Over Time'}, xlabel='Time', ylabel='Normalized Diffusion KL Score'>)

# %%
# Identifies cutoff for localized genes
knee = lmd.find_knee(lmd_scores)

# %%
plt.plot(sorted(lmd_scores))
plt.plot(knee, sorted(lmd_scores)[knee], 'ro')

plt.show()

# %%
LMDs = list(lmd_scores.sort_values()[:knee].index)

# %%
LMDs[:10]
# Out:
# ['DUSP15',
#  'SULT1C2',
#  'C16orf89',
#  'CIBAR2',
#  'HLA-DPA1',
#  'IQGAP2',
#  'CAPSL',
#  'DYNLT5',
#  'ODAD2',
#  'C20orf85']

# %%
# Subsets LMDs for identifying gene modules.
lmd_dat = dat[dat.index.isin(LMDs)]

# %%
# Calculates pairwise distance between genes' expression patterns.
dist = cluster.distance(lmd_dat, method = 'jaccard')

# %%
dist = dist.loc[~dist.index.duplicated(keep='first')]
dist = dist.loc[:, ~dist.columns.duplicated(keep='first')]
dist
# Out:
# feature_name       TTLL10    CFAP74     MMEL1     TTC34      TP73    DRAXIN  \
# feature_name
# TTLL10           0.000000  0.623588  0.911312  0.753823  0.769472  0.952162
# CFAP74           0.623588  0.000000  0.923973  0.747136  0.747045  0.983201
# MMEL1            0.911312  0.923973  0.000000  0.948946  0.929724  0.842978
# TTC34            0.753823  0.747136  0.948946  0.000000  0.843750  0.979704
# TP73             0.769472  0.747045  0.929724  0.843750  0.000000  0.972050
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000228933  0.999034  1.000000  0.997684  1.000000  0.999424  0.996035
# NUDT10           0.999032  1.000000  0.998843  1.000000  1.000000  0.996029
# PAGE5            0.989331  0.988197  0.998075  0.987013  0.993649  0.996054
# NXF2B            0.988281  0.988121  0.997297  0.988543  0.993043  0.999209
# TRPC5OS          0.998064  1.000000  0.998457  0.998377  0.999424  0.998416
#
# feature_name         PDPN  ENSG00000231606  KAZN-AS1     FHAD1  ...  \
# feature_name                                                    ...
# TTLL10           0.979775         0.841068  0.838277  0.761414  ...
# CFAP74           0.981089         0.863546  0.853966  0.770708  ...
# MMEL1            0.965182         0.912247  0.935591  0.853318  ...
# TTC34            0.985058         0.885805  0.873278  0.862548  ...
# TP73             0.857245         0.901654  0.908329  0.812098  ...
# ...                   ...              ...       ...       ...  ...
# ENSG00000228933  0.999675         0.996287  1.000000  1.000000  ...
# NUDT10           0.997062         1.000000  1.000000  0.999574  ...
# PAGE5            0.998374         0.990111  0.990521  0.995313  ...
# NXF2B            1.000000         0.992547  0.992038  0.994872  ...
# TRPC5OS          0.999674         0.998764  1.000000  0.998722  ...
#
# feature_name     LINC01664  ENSG00000279440     PVALB  ENSG00000287171  \
# feature_name
# TTLL10            0.996120         0.999033  1.000000         1.000000
# CFAP74            0.997859         1.000000  1.000000         1.000000
# MMEL1             0.997683         0.997296  0.998458         0.998071
# TTC34             0.998377         1.000000  0.998382         1.000000
# TP73              0.998847         1.000000  1.000000         1.000000
# ...                    ...              ...       ...              ...
# ENSG00000228933   1.000000         1.000000  0.958333         1.000000
# NUDT10            1.000000         1.000000  1.000000         1.000000
# PAGE5             1.000000         1.000000  1.000000         0.965517
# NXF2B             1.000000         1.000000  1.000000         1.000000
# TRPC5OS           0.952381         1.000000  1.000000         1.000000
#
# feature_name         TLR7  ENSG00000228933    NUDT10     PAGE5     NXF2B  \
# feature_name
# TTLL10           0.996124         0.999034  0.999032  0.989331  0.988281
# CFAP74           0.995713         1.000000  1.000000  0.988197  0.988121
# MMEL1            0.997684         0.997684  0.998843  0.998075  0.997297
# TTC34            0.995122         1.000000  1.000000  0.987013  0.988543
# TP73             0.997692         0.999424  1.000000  0.993649  0.993043
# ...                   ...              ...       ...       ...       ...
# ENSG00000228933  1.000000         0.000000  1.000000  1.000000  1.000000
# NUDT10           1.000000         1.000000  0.000000  1.000000  1.000000
# PAGE5            1.000000         1.000000  1.000000  0.000000  1.000000
# NXF2B            1.000000         1.000000  1.000000  1.000000  0.000000
# TRPC5OS          0.954545         1.000000  1.000000  1.000000  1.000000
#
# feature_name      TRPC5OS
# feature_name
# TTLL10           0.998064
# CFAP74           1.000000
# MMEL1            0.998457
# TTC34            0.998377
# TP73             0.999424
# ...                   ...
# ENSG00000228933  1.000000
# NUDT10           1.000000
# PAGE5            1.000000
# NXF2B            1.000000
# TRPC5OS          0.000000
#
# [2464 rows x 2464 columns]

# %%
# Groups similarly expressed / patterned genes.
gene_sets = cluster.modules(dist, clustering_method = "average", min_gene = 10, deepSplit = 2)
# Out:
# ..cutHeight not given, setting it to 0.9947392707980839  ===>  99% of the (truncated) height range in dendro.
# ..done.
# /notebooks/pylmd/pylmd/cluster.py:121: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   med_pos = (gene_partition.index.to_series().map(label_pos).groupby(gene_partition).median().sort_values())
# /notebooks/pylmd/pylmd/cluster.py:149: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gene_sets = gene_partition.groupby(gene_partition).apply(lambda x: x.index.tolist()).to_dict()

# %%
sc.pl.umap(adata, color = 'cell_type')

# %%
sc.pl.umap(adata, color = gene_sets[14][0:4], use_raw=False)

# %%
sc.pl.umap(adata, color = gene_sets[5][0:4], use_raw=False)

# %%
sc.pl.umap(adata, color = 'MKI67', use_raw=False)

# %%
sc.pl.umap(adata, color = 'donor_id')

# %%
sc.pl.umap(adata, color = gene_sets[7][0:4], use_raw=False)

# %%
sc.pl.umap(adata, color = 'DDX3Y', use_raw=False)
